# %%
committee_ids = {
    "house_energy_and_commerce": {
        "116": {
            "P000034", "Nanette Barragán", "Ben Ray Luján", "Doris Matsui", "Aston Donald McEachin", 
            "Jerry McNerney", "Tom O'Halleran", "Scott Peters", "Bobby Rush", "Raul Ruiz", "Dave Loebsack", 
            "John Sarbanes", "Jan Schakowsky", "Kurt Schrader", "Darren Soto", "Paul Tonko", "Marc Veasey", 
            "Michael Doyle", "Lisa Blunt Rochester", "G.K. Butterfield", "Tony Cárdenas", "Kathy Castor", 
            "Yvette D. Clarke", "Diana DeGette", "Debbie Dingell", "Annie Kuster", "Eliot Engel", "Anna Eshoo", 
            "Robin Kelly", "Joseph Kennedy III", "Peter Welch", "Greg Walden", "Cathy McMorris Rodgers", 
            "David McKinley", "Markwayne Mullin", "Peter G. Olson", "Steve Scalise", "John Shimkus", 
            "Fred Upton", "Tim Walberg", "Billy Long", "Bob Latta", "Gus M. Bilirakis", "Susan Brooks", 
            "Larry Bucshon", "Michael C. Burgess", "Earl Carter", "Jeff Duncan", "Bill Flores", "Greg Gianforte", 
            "H. Morgan Griffith", "Brett Guthrie", "Richard Hudson", "Bill Johnson", "Adam Kinzinger"
        },
        "117": {
            "P000034", "Jan Schakowsky", "Darren Soto", "Anna Eshoo", "Diana DeGette", "John Sarbanes", 
            "Paul Tonko", "Yvette D. Clarke", "Scott Peters", "Lisa Blunt Rochester", "Lori Trahan", "Kim Schrier", 
            "Kathy Castor", "Kurt Schrader", "Tony Cárdenas", "Raul Ruiz", "Debbie Dingell", "Annie Kuster", 
            "Kathleen Rice", "Bobby Rush", "Michael Doyle", "G.K. Butterfield", "Doris Matsui", "Jerry McNerney", 
            "Peter Welch", "Marc Veasey", "Robin Kelly", "Nanette Barragán", "Aston Donald McEachin", 
            "Tom O'Halleran", "Angie Craig", "Lizzie Pannill Fletcher", "Cathy McMorris Rodgers", "Daniel Crenshaw", 
            "John Joyce", "Kelly Armstrong", "Fred Upton", "Steve Scalise", "Brett Guthrie", "H. Morgan Griffith", 
            "Gus M. Bilirakis", "Billy Long", "Larry Bucshon", "Tim Walberg", "Earl Carter", "Jeff Duncan", 
            "Markwayne Mullin", "Greg Pence", "John Curtis", "Debbie Lesko", "Bob Latta", "David McKinley", 
            "Neal Dunn", "Michael C. Burgess", "Adam Kinzinger", "Bill Johnson", "Gary Palmer", "Richard Hudson"
        },
    },
    "house_financial_services": {
        "116": {
            "Maxine Waters", "Alma Adams", "Carolyn B. Maloney", "Ben McAdams", "Gregory W. Meeks", 
            "Alexandria Ocasio-Cortez", "Ed Perlmutter", "Dean Phillips", "Katie Porter", "Ayanna Pressley", 
            "Michael F.Q. San Nicolas", "David Scott", "Brad Sherman", "Rashida Tlaib", "Juan Vargas", 
            "Nydia Velazquez", "Jennifer Wexton", "Stephen Lynch", "Cindy Axne", "Jesus Garcia", "Joyce Beatty", 
            "Sean Casten", "William Lacy Clay", "Emanuel Cleaver", "Madeleine Dean", "Bill Foster", "Tulsi Gabbard", 
            "Sylvia Garcia", "Vicente Gonzalez Jr.", "Josh Gottheimer", "Al Green", "Denny Heck", "Jim Himes", 
            "Alfred Lawson", "Patrick T. McHenry", "John Rose", "Alexander Mooney", "Bill Posey", 
            "Denver Lee Riggleman III", "Blaine Luetkemeyer", "Bryan Steil", "Steve Stivers", "Scott Tipton", 
            "Ann Wagner", "Roger Williams", "Lee Zeldin", "Frank Lucas", "Andy Barr", "Ted Budd", 
            "Warren Davidson", "Sean Duffy", "Tom Emmer", "Barry Loudermilk", "Anthony Gonzalez", "Lance Gooden", 
            "French Hill", "Trey Hollingsworth", "Bill Huizenga", "Peter King", "David Kustoff", "William Timmons"
        },
        "117": {
            "Maxine Waters", "Carolyn B. Maloney", "Nikema Williams", "Jake Auchincloss", "Sylvia Garcia", 
            "Nydia Velazquez", "Josh Gottheimer", "Brad Sherman", "Gregory W. Meeks", "David Scott", "Al Green", 
            "Emanuel Cleaver", "Ed Perlmutter", "Jim Himes", "Bill Foster", "Joyce Beatty", "Juan Vargas", 
            "Vicente Gonzalez Jr.", "Jesus Garcia", "Alfred Lawson", "Michael F.Q. San Nicolas", "Cindy Axne", 
            "Sean Casten", "Ayanna Pressley", "Ritchie Torres", "Stephen Lynch", "Alma Adams", "Rashida Tlaib", 
            "Madeleine Dean", "Alexandria Ocasio-Cortez", "Patrick T. McHenry", "Tom Emmer", "Frank Lucas", 
            "Bill Posey", "Blaine Luetkemeyer", "Bill Huizenga", "Steve Stivers", "Ann Wagner", "Andy Barr", 
            "Roger Williams", "French Hill", "Barry Loudermilk", "Lee Zeldin", "Alexander Mooney", "Warren Davidson", 
            "Ted Budd", "David Kustoff", "Trey Hollingsworth", "Anthony Gonzalez", "John Rose", "William Timmons", 
            "Van Taylor", "Bryan Steil", "Lance Gooden"
        },
    },
    "senate_banking": {
        "116": {
            "Sherrod Brown", "Bob Menendez", "Kyrsten Sinema", "Tina Smith", "Catherine Cortez Masto", 
            "Chris Van Hollen", "Brian E. Schatz", "Elizabeth Warren", "Mark Warner", "Jon Tester", "Jack Reed", 
            "Mike Crapo", "Pat Toomey", "Tim Scott", "Richard Shelby", "Kevin Cramer", "Jerry Moran", 
            "Martha McSally", "John Neely Kennedy", "Thom Tillis", "Mike Rounds", "Tom Cotton", "Ben Sasse"
        },
        "117": {
            "Sherrod Brown", "Raphael Warnock", "Jon Ossoff", "Kyrsten Sinema", "Tina Smith", 
            "Catherine Cortez Masto", "Chris Van Hollen", "Elizabeth Warren", "Mark Warner", "Jon Tester", 
            "Bob Menendez", "Jack Reed", "Pat Toomey", "Kevin Cramer", "Jerry Moran", "Cynthia Lummis", 
            "Bill Hagerty", "John Neely Kennedy", "Thom Tillis", "Mike Rounds", "Tim Scott", "Mike Crapo", 
            "Richard Shelby", "Steve Daines"
        },
    },
    "senate_help": {
        "116": {
            "Patty Murray", "Christopher S. Murphy", "Jacky Rosen", "Tina Smith", "Maggie Hassan", "Tim Kaine", 
            "Elizabeth Warren", "Bob Casey Jr.", "Tammy Baldwin", "Bernie Sanders", "Richard Burr", 
            "Johnny Isakson", "Mike Braun", "Mitt Romney", "Tim Scott", "Lisa Murkowski", "Bill Cassidy", 
            "Susan Collins", "Rand Paul"
        },
        "117": {
            "Patty Murray", "Tim Kaine", "Bob Casey Jr.", "Bernie Sanders", "John Hickenlooper", "Ben Ray Luján", 
            "Jacky Rosen", "Tina Smith", "Maggie Hassan", "Christopher S. Murphy", "Tammy Baldwin", "Richard Burr", 
            "Susan Collins", "Jerry Moran", "Tommy Tuberville", "Mitt Romney", "Tim Scott", "Roger Marshall", 
            "Mike Braun", "Lisa Murkowski", "Rand Paul", "Bill Cassidy"
        },
    },
    "house_appropriations": {
        "116": {
            "Nita Lowey", "Grace Meng", "Chellie Pingree", "Mark Pocan", "David Price", "Mike Quigley", 
            "Dutch Ruppersberger", "Lucille Roybal-Allard", "Tim Ryan", "José Serrano", "Norma Torres", 
            "Peter Visclosky", "Debbie Wasserman Schultz", "Bonnie Watson Coleman", "Betty McCollum", 
            "Brenda Lawrence", "Barbara Lee", "Rosa L. DeLauro", "Sanford Bishop Jr.", "Cheri Bustos", 
            "Matt Cartwright", "Ed Case", "Katherine Clark", "Charlie Crist", "Henry Cuellar", "Pete Aguilar", 
            "Lois Frankel", "Marcy Kaptur", "Derek Kilmer", "Ann Kirkpatrick", "Tom Cole Vice", "Kay Granger", 
            "Robert Aderholt", "Hal Rogers", "John Moolenaar", "Dan Newhouse", "Steven Palazzo", "Martha Roby", 
            "John Rutherford", "Michael K. Simpson", "Chris Stewart", "Steve Womack", "Mark Amodei", 
            "Ken Calvert", "John Carter", "Mario Diaz-Balart", "Charles J. Fleischmann", "Jeffrey Fortenberry", 
            "Andrew Harris", "Jaime Herrera Beutler", "William Hurd", "David Joyce"
        },
        "117": {
            "Rosa L. DeLauro", "Charlie Crist", "Lois Frankel", "Cheri Bustos", "Bonnie Watson Coleman", 
            "Brenda Lawrence", "Norma Torres", "Ann Kirkpatrick", "Ed Case", "Adriano Espaillat", "Josh Harder", 
            "Jennifer Wexton", "David Trone", "Lauren Underwood", "Susie Lee", "Marcy Kaptur", "Pete Aguilar", 
            "Katherine Clark", "Lucille Roybal-Allard", "Sanford Bishop Jr.", "Barbara Lee", "Betty McCollum", 
            "Tim Ryan", "Dutch Ruppersberger", "Debbie Wasserman Schultz", "Henry Cuellar", "David Price", 
            "Chellie Pingree", "Mike Quigley", "Derek Kilmer", "Matt Cartwright", "Grace Meng", "Mark Pocan", 
            "Kay Granger", "Dan Newhouse", "John Moolenaar", "John Rutherford", "Benjamin Lee Cline", 
            "Guy Reschenthaler", "Mike Garcia", "Ashley Hinson", "David G. Valadao", "Tony Gonzales", 
            "Hal Rogers", "Robert Aderholt", "Steven Palazzo", "Jeffrey Fortenberry", "John Carter", 
            "Ken Calvert", "Tom Cole", "Mario Diaz-Balart", "Steve Womack", "Charles J. Fleischmann", 
            "Jaime Herrera Beutler", "David Joyce", "Andrew Harris", "Mark Amodei", "Chris Stewart", 
            "Michael K. Simpson"
        },
    },
    "house_oversight_and_reform": {
        "116": {
            "Ayanna Pressley", "Eleanor Holmes Norton", "Alexandria Ocasio-Cortez", "Stacey Plaskett", 
            "Jamie Raskin", "Carolyn B. Maloney", "Harley Rouda", "John Sarbanes", "Jackie Speier", 
            "Rashida Tlaib", "Debbie Wasserman Schultz", "Peter Welch", "Brenda Lawrence", "Stephen Lynch", 
            "Jimmy Gomez", "Gerald Edward Connolly", "Jim Cooper", "Mark DeSaulnier", "William Lacy Clay", 
            "Katie Hill", "Robin Kelly", "Ro Khanna", "Raja Krishnamoorthi", "Kweisi Mfume", "Jim Jordan", 
            "Kelly Armstrong", "Mark Meadows", "Carol Miller", "Ralph Norman", "Chip Roy", "Greg Steube", 
            "Thomas Massie", "Michael Cloud", "James Comer Jr.", "Virginia Foxx", "Bob Gibbs", "Paul Gosar", 
            "Mark Green", "Glenn Grothman", "Jody Hice", "Clay Higgins"
        },
        "117": {
            "Carolyn B. Maloney", "Ayanna Pressley", "Jimmy Gomez", "Brenda Lawrence", "Mark DeSaulnier", 
            "Alexandria Ocasio-Cortez", "Eleanor Holmes Norton", "Stephen Lynch", "Jim Cooper", 
            "Gerald Edward Connolly", "Raja Krishnamoorthi", "Jamie Raskin", "Ro Khanna", "Kweisi Mfume", 
            "Rashida Tlaib", "Robin Kelly", "Katie Porter", "Cori Bush", "Danny K. Davis", 
            "Debbie Wasserman Schultz", "Peter Welch", "Hank Johnson", "John Sarbanes", "Jackie Speier", 
            "James Comer Jr.", "Jim Jordan", "Virginia Foxx", "Jody Hice", "Glenn Grothman", "Michael Cloud", 
            "Bob Gibbs", "Clay Higgins", "Fred Keller", "Ralph Norman", "Pete Sessions", "Andy Biggs", 
            "Byron Donalds", "Nancy Mace", "Yvette Herrell", "Jacob LaTurner", "Pat Fallon", "Andrew Clyde", 
            "Scott Franklin"
        },
    },
    "house_ways_and_means": {
        "116": {
            "Richard Neal", "Brad Schneider", "Jimmy Panetta", "Bill Pascrell", "Linda Sánchez", "Terri Sewell", 
            "Gwen Moore", "Tom Suozzi", "Mike Thompson", "John Larson", "Stephanie Murphy", 
            "Donald Sternoff Beyer Jr.", "Earl Blumenauer", "Brendan Boyle", "Judy Chu", "Danny K. Davis", 
            "Suzan DelBene", "Lloyd Doggett", "Dwight Evans", "Jimmy Gomez", "Brian Higgins", "Steven Horsford", 
            "Dan Kildee", "Ronald James Kind", "Kevin Brady", "Jodey Arrington", "Devin Nunes", "Tom Reed", 
            "Tom Rice", "David Schweikert", "Adrian Smith", "Jason Smith", "Jackie Walorski", "Brad Wenstrup", 
            "Kenny Marchant", "Ron Estes", "Vern Buchanan", "Darin LaHood", "Drew Ferguson", 
            "George E.B. Holding", "Mike Kelly"
        },
        "117": {
            "Richard Neal", "Judy Chu", "Gwen Moore", "Dan Kildee", "Dwight Evans", "Tom Suozzi", "Brad Schneider", 
            "Jimmy Panetta", "Stephanie Murphy", "Jimmy Gomez", "Steven Horsford", "Brendan Boyle", 
            "Donald Sternoff Beyer Jr.", "Suzan DelBene", "Ronald James Kind", "Lloyd Doggett", "Mike Thompson", 
            "John Larson", "Earl Blumenauer", "Terri Sewell", "Bill Pascrell", "Danny K. Davis", "Linda Sánchez", 
            "Brian Higgins", "Stacey Plaskett", "Kevin Brady", "Jodey Arrington", "Drew Ferguson", "Ron Estes", 
            "Lloyd Smucker", "Kevin Hern", "Carol Miller", "Brad Wenstrup", "Darin LaHood", "Vern Buchanan", 
            "Adrian Smith", "Tom Reed", "Mike Kelly", "Jason Smith", "Tom Rice", "David Schweikert", 
            "Jackie Walorski"
        },
    },
    "senate_appropriations": {
        "116": {
            "Patrick Leahy", "Chris Van Hollen", "Joe Manchin III", "Christopher S. Murphy", "Tammy Baldwin", 
            "Brian E. Schatz", "Chris Coons", "Jeff Merkley", "Jeanne Shaheen", "Jon Tester", "Jack Reed", 
            "Dick Durbin", "Dianne Feinstein", "Patty Murray", "Richard Shelby", "James Lankford", 
            "Mitch McConnell", "Marco Rubio", "Steve Daines", "Cindy Hyde-Smith", "John Neely Kennedy", 
            "Shelley Moore Capito", "John Boozman", "John Hoeven", "Jerry Moran", "Roy Blunt", "Lindsey Graham", 
            "Lisa Murkowski", "Susan Collins"
        },
        "117": {
            "Patrick Leahy", "Martin Heinrich", "Chris Van Hollen", "Joe Manchin III", "Tammy Baldwin", 
            "Brian E. Schatz", "Chris Coons", "Jeff Merkley", "Jeanne Shaheen", "Jon Tester", "Jack Reed", 
            "Dick Durbin", "Dianne Feinstein", "Patty Murray", "Christopher S. Murphy", "Richard Shelby", 
            "Marco Rubio", "Bill Hagerty", "Mike Braun", "Cindy Hyde-Smith", "John Neely Kennedy", 
            "Shelley Moore Capito", "John Boozman", "John Hoeven", "Jerry Moran", "Roy Blunt", "Lindsey Graham", 
            "Lisa Murkowski", "Susan Collins", "Mitch McConnell"
        },
    },
    "senate_finance": {
        "116": {
            "Ron Wyden", "Maria Cantwell", "Catherine Cortez Masto", "Maggie Hassan", "Sheldon Whitehouse", 
            "Mark Warner", "Bob Casey Jr.", "Michael Bennet", "Sherrod Brown", "Ben Cardin", "Tom Carper", 
            "Bob Menendez", "Debbie Stabenow", "Chuck Grassley", "Mike Crapo", "Todd C. Young", "Steve Daines", 
            "James Lankford", "Bill Cassidy", "Tim Scott", "Pat Toomey", "Rob Portman", "Johnny Isakson", 
            "Richard Burr", "John Thune", "John Cornyn"
        },
        "117": {
            "Ron Wyden", "Michael Bennet", "Sherrod Brown", "Elizabeth Warren", "Catherine Cortez Masto", 
            "Maggie Hassan", "Sheldon Whitehouse", "Mark Warner", "Bob Casey Jr.", "Ben Cardin", "Tom Carper", 
            "Bob Menendez", "Maria Cantwell", "Debbie Stabenow", "Mike Crapo", "Pat Toomey", "Rob Portman", 
            "Richard Burr", "Ben Sasse", "Todd C. Young", "Steve Daines", "James Lankford", "Bill Cassidy", 
            "Tim Scott", "John Thune", "John Cornyn", "Chuck Grassley", "John Barrasso"
        },
    }
}

# %%
import re
from copy import deepcopy
import pandas as pd

df = pd.read_csv("../data/cleaned/2014-2023/stocks.csv")
name_to_id = dict(zip(df["member"], df["member_id"]))
last_unique = (
    df[['last_name', 'member_id']]
    .drop_duplicates()
    .groupby('last_name')
    .filter(lambda g: g['member_id'].nunique() == 1)
)

last_to_id = dict(
    zip(last_unique['last_name'].str.lower(), last_unique['member_id'])
)

# quick helper:  is this already a 7-char Bioguide id?
ID_PAT = re.compile(r"^[A-Z]\d{6}$")
def looks_like_id(s): return bool(ID_PAT.match(s))

# -------------------------------------------------------------
# 2)  PASS THROUGH committee_ids AND REPLACE
# -------------------------------------------------------------
clean = deepcopy(committee_ids)
unresolved = []         # for anything we still can’t map

for cmt, congresses in clean.items():
    for cong, members in congresses.items():
        new_set = set()
        for m in members:
            if looks_like_id(m):
                new_set.add(m)                   # already an ID
                continue

            # (a) exact full-name match
            if m in name_to_id:
                new_set.add(name_to_id[m])
                continue

            # (b) unique last-name match
            last = m.split()[-1].lower()
            if last in last_to_id:
                new_set.add(last_to_id[last])
                continue

            # (c) give up for now — keep original string
            new_set.add(m)
            unresolved.append((cmt, cong, m))

        congresses[cong] = new_set

# -------------------------------------------------------------
# 3)  REPORT WHAT’S LEFT
# -------------------------------------------------------------
if unresolved:
    print("⚠️  STILL UNMAPPED (needs manual check):")
    for cmt, cong, name in unresolved:
        print(f"  • [{cmt} | {cong}]  {name}")
else:
    print("✅ All committee names converted to IDs with 100 % confidence.")
# Out:
# ⚠️  STILL UNMAPPED (needs manual check):
#   • [house_energy_and_commerce | 116]  Dave Loebsack
#   • [house_energy_and_commerce | 116]  Greg Walden
#   • [house_energy_and_commerce | 116]  Tim Walberg
#   • [house_energy_and_commerce | 116]  Ben Ray Luján
#   • [house_energy_and_commerce | 116]  Bill Johnson
#   • [house_energy_and_commerce | 116]  Susan Brooks
#   • [house_energy_and_commerce | 116]  Raul Ruiz
#   • [house_energy_and_commerce | 116]  Brett Guthrie
#   • [house_energy_and_commerce | 116]  Jerry McNerney
#   • [house_energy_and_commerce | 116]  Yvette D. Clarke
#   • [house_energy_and_commerce | 116]  Michael Doyle
#   • [house_energy_and_commerce | 116]  Anna Eshoo
#   • [house_energy_and_commerce | 116]  John Sarbanes
#   • [house_energy_and_commerce | 116]  Cathy McMorris Rodgers
#   • [house_energy_and_commerce | 116]  Steve Scalise
#   • [house_energy_and_commerce | 116]  Darren Soto
#   • [house_energy_and_commerce | 116]  Richard Hudson
# ...
