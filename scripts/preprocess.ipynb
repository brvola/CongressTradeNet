# %%
import pandas

# %%
SUFFIX = "2021-2023_20250526"
PREFIX = "../data/"

TRADES_PATH = f"{PREFIX}trades/trades_{SUFFIX}.csv"
VOTES_PATH = f"{PREFIX}votes/votes_by_member_{SUFFIX}.csv"
VOTE_SUMMARIES_PATH = f"{PREFIX}votes/votes_summary_{SUFFIX}.csv"

OUTPUT_DIR = "./data/cleaned"

# %%
trades_df = pandas.read_csv(TRADES_PATH)
votes_df = pandas.read_csv(VOTES_PATH)
vote_summaries_df = pandas.read_csv(VOTE_SUMMARIES_PATH)
# Out:
# /var/folders/jx/7k6544kn35n00wd0kcwf51300000gn/T/ipykernel_63692/2711763335.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   votes_df = pandas.read_csv(VOTES_PATH)

# %%
trades_df.head()
trades_df["asset_type"].unique()
trades_df.drop(columns=["asset_type"], inplace=True)

# %%
trades_df.head()
trades_df["comment"].unique()
trades_df.drop(columns=["comment"], inplace=True)

# %%
trades_df.head()
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0           2021.0      10/04/2021       2021-09-27  joint     BP
# 1           2021.0      10/04/2021       2021-09-13  joint    XOM
# 2           2021.0      10/04/2021       2021-09-10  joint   ILPT
# 3           2021.0      10/04/2021       2021-09-28  joint     PM
# 4           2021.0      10/04/2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount district state  \
# 0   $1,001 - $15,000     NC05    NC
# 1   $1,001 - $15,000     NC05    NC
# 2  $15,001 - $50,000     NC05    NC
# ...

# %%
print("Types of trades:")
print(trades_df["type"].unique())
print()
print("Senators:")
print(trades_df["is_senator"].unique())
print()
print("Owner")
print(trades_df["owner"].unique())
print()
print("Tickers")
print(trades_df["ticker"].unique())
print(len(trades_df["ticker"].unique()), "unique tickers in trades")
print()
print("Sector")
print(trades_df["sector"].unique())
print()
print("Industry")
print(trades_df["industry"].unique())
# Out:
# Types of trades:
# ['purchase' 'sale_partial' 'sale_full' 'exchange' 'sale']
#
# Senators:
# [False]
#
# Owner
# ['joint' 'self' nan 'dependent' '--']
#
# Tickers
# ['BP' 'XOM' 'ILPT' ... 'UGI' 'VALE' 'XYIGY']
# 1606 unique tickers in trades
#
# Sector
# ['Energy' 'Real Estate' 'Consumer Non-Durables' 'Finance' nan 'Technology'
#  'Public Utilities' 'Consumer Staples' 'Health Care' 'Utilities'
#  'Consumer Discretionary' 'Consumer Services' 'Basic Materials'
#  'Capital Goods' 'Miscellaneous' 'Basic Industries' 'Telecommunications'
#  'Industrials' 'Consumer Durables' 'Transportation']
#
# Industry
# ['Integrated oil Companies' 'Real Estate Investment Trusts'
#  'Farming/Seeds/Milling' 'Investment Bankers/Brokers/Service'
#  'Finance: Consumer Services' nan 'Semiconductors'
#  'Computer Manufacturing' 'Computer Software: Prepackaged Software'
#  'Electric Utilities: Central' 'Paper' 'Investment Managers'
#  'Major Pharmaceuticals' 'Power Generation' 'EDP Services'
# ...

# %%
trades_df["disclosure_date"] = trades_df["disclosure_date"].str.replace("/", "-")
trades_df.head()
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0           2021.0      10-04-2021       2021-09-27  joint     BP
# 1           2021.0      10-04-2021       2021-09-13  joint    XOM
# 2           2021.0      10-04-2021       2021-09-10  joint   ILPT
# 3           2021.0      10-04-2021       2021-09-28  joint     PM
# 4           2021.0      10-04-2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount     representative district state  \
# 0   $1,001 - $15,000      Virginia Foxx     NC05    NC
# ...

# %%
trades_df.head()
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0           2021.0      10/04/2021       2021-09-27  joint     BP
# 1           2021.0      10/04/2021       2021-09-13  joint    XOM
# 2           2021.0      10/04/2021       2021-09-10  joint   ILPT
# 3           2021.0      10/04/2021       2021-09-28  joint     PM
# 4           2021.0      10/04/2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount     representative district state  \
# 0   $1,001 - $15,000      Virginia Foxx     NC05    NC
# ...
